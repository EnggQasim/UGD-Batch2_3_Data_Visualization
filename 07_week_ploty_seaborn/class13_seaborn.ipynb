# %%
import seaborn as sns
import pandas as pd

df = sns.load_dataset("tips")

df.info()
display(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
#  https://github.com/mwaskom/seaborn-data

# %%
import seaborn as sns
import pandas as pd

df = sns.load_dataset("tips")

sns.scatterplot(data=df,
                x="total_bill",
                y="tip"
               )
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.__version__
# Out:
# '0.11.2'

# %%
# !pip install --upgrade seaborn --force
# Out:
# Collecting seaborn
#   Using cached seaborn-0.12.2-py3-none-any.whl (293 kB)
# Collecting numpy!=1.24.0,>=1.17 (from seaborn)
#   Using cached numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
# Collecting pandas>=0.25 (from seaborn)
#   Using cached pandas-1.3.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
# Collecting matplotlib!=3.6.1,>=3.1 (from seaborn)
#   Using cached matplotlib-3.5.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
# Collecting typing_extensions (from seaborn)
#   Using cached typing_extensions-4.6.3-py3-none-any.whl (31 kB)
# Collecting cycler>=0.10 (from matplotlib!=3.6.1,>=3.1->seaborn)
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools>=4.22.0 (from matplotlib!=3.6.1,>=3.1->seaborn)
#   Using cached fonttools-4.38.0-py3-none-any.whl (965 kB)
# Collecting kiwisolver>=1.0.1 (from matplotlib!=3.6.1,>=3.1->seaborn)
#   Using cached kiwisolver-1.4.4-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.1 MB)
# Collecting packaging>=20.0 (from matplotlib!=3.6.1,>=3.1->seaborn)
#   Using cached packaging-23.1-py3-none-any.whl (48 kB)
# Collecting pillow>=6.2.0 (from matplotlib!=3.6.1,>=3.1->seaborn)
#   Using cached Pillow-9.5.0-cp37-cp37m-manylinux_2_28_x86_64.whl (3.4 MB)
# Collecting pyparsing>=2.2.1 (from matplotlib!=3.6.1,>=3.1->seaborn)
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Collecting python-dateutil>=2.7 (from matplotlib!=3.6.1,>=3.1->seaborn)
#   Using cached python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Collecting pytz>=2017.3 (from pandas>=0.25->seaborn)
#   Downloading pytz-2023.3-py2.py3-none-any.whl (502 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.3/502.3 kB 2.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting six>=1.5 (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn)
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: pytz, typing_extensions, six, pyparsing, pillow, packaging, numpy, fonttools, cycler, python-dateutil, kiwisolver, pandas, matplotlib, seaborn
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2022.6
#     Uninstalling pytz-2022.6:
#       Successfully uninstalled pytz-2022.6
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.6.2
#     Uninstalling typing_extensions-4.6.2:
#       Successfully uninstalled typing_extensions-4.6.2
#   Attempting uninstall: six
#     Found existing installation: six 1.15.0
#     Uninstalling six-1.15.0:
#       Successfully uninstalled six-1.15.0
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 9.5.0
#     Uninstalling Pillow-9.5.0:
#       Successfully uninstalled Pillow-9.5.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 22.0
#     Uninstalling packaging-22.0:
#       Successfully uninstalled packaging-22.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
#   Attempting uninstall: fonttools
#     Found existing installation: fonttools 4.25.0
#     Uninstalling fonttools-4.25.0:
#       Successfully uninstalled fonttools-4.25.0
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.11.0
#     Uninstalling cycler-0.11.0:
#       Successfully uninstalled cycler-0.11.0
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.2
#     Uninstalling python-dateutil-2.8.2:
#       Successfully uninstalled python-dateutil-2.8.2
#   Attempting uninstall: kiwisolver
#     Found existing installation: kiwisolver 1.4.2
#     Uninstalling kiwisolver-1.4.2:
#       Successfully uninstalled kiwisolver-1.4.2
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.4
#     Uninstalling pandas-1.3.4:
#       Successfully uninstalled pandas-1.3.4
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.5.0
#     Uninstalling matplotlib-3.5.0:
#       Successfully uninstalled matplotlib-3.5.0
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.11.2
#     Uninstalling seaborn-0.11.2:
#       Successfully uninstalled seaborn-0.11.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.24 requires pathlib, which is not installed.
# spyder 3.3.6 requires pyqtwebengine<5.13; python_version >= "3", which is not installed.
# flask-appbuilder 4.1.4 requires Flask<3,>=2, but you have flask 1.1.2 which is incompatible.
# flask-appbuilder 4.1.4 requires SQLAlchemy<1.5, but you have sqlalchemy 2.0.15 which is incompatible.
# flask-jwt-extended 4.4.4 requires Flask<3.0,>=2.0, but you have flask 1.1.2 which is incompatible.
# pyrush 1.0.8 requires spacy>=3.0.0, but you have spacy 2.2.4 which is incompatible.
# apache-airflow 2.4.3 requires alembic<2.0,>=1.5.1, but you have alembic 1.4.1 which is incompatible.
# apache-airflow 2.4.3 requires flask<2.3,>=2.2, but you have flask 1.1.2 which is incompatible.
# apache-airflow 2.4.3 requires jinja2>=3.0.0, but you have jinja2 2.11.3 which is incompatible.
# autoviz 0.1.58 requires bokeh>=2.4.2, but you have bokeh 2.0.0 which is incompatible.
# conda-repo-cli 1.0.24 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.24 requires nbformat==5.4.0, but you have nbformat 5.5.0 which is incompatible.
# conda-repo-cli 1.0.24 requires requests==2.28.1, but you have requests 2.26.0 which is incompatible.
# confection 0.0.4 requires srsly<3.0.0,>=2.4.0, but you have srsly 1.0.6 which is incompatible.
# confection 0.0.4 requires typing-extensions<4.5.0,>=3.7.4.1; python_version < "3.8", but you have typing-extensions 4.6.3 which is incompatible.
# dataprep 0.4.3 requires flask<3,>=2, but you have flask 1.1.2 which is incompatible.
# dataprep 0.4.3 requires jinja2<4,>=3, but you have jinja2 2.11.3 which is incompatible.
# dataprep 0.4.3 requires regex<2022.0.0,>=2021.8.3, but you have regex 2022.10.31 which is incompatible.
# dataprep 0.4.3 requires sqlalchemy<2.0.0,>=1.4.32, but you have sqlalchemy 2.0.15 which is incompatible.
# dtale 2.9.0 requires packaging<=21.0; python_version == "3.7", but you have packaging 23.1 which is incompatible.
# dtale 2.9.0 requires scikit-learn==1.0.2; python_version == "3.7", but you have scikit-learn 0.23.2 which is incompatible.
# dtale 2.9.0 requires scipy==1.7.3; python_version == "3.7", but you have scipy 1.5.4 which is incompatible.
# dtale 2.9.0 requires statsmodels==0.12.2; python_version == "3.7", but you have statsmodels 0.13.5 which is incompatible.
# feather 0.1.2 requires numpy==1.20.2, but you have numpy 1.21.6 which is incompatible.
# feather 0.1.2 requires Pillow==8.2.0, but you have pillow 9.5.0 which is incompatible.
# feather 0.1.2 requires requests==2.25.1, but you have requests 2.26.0 which is incompatible.
# heroku 0.1.4 requires python-dateutil==1.5, but you have python-dateutil 2.8.2 which is incompatible.
# httpcore 0.15.0 requires h11<0.13,>=0.11, but you have h11 0.14.0 which is incompatible.
# klib 1.0.1 requires Jinja2<4.0.0,>=3.0.3, but you have jinja2 2.11.3 which is incompatible.
# klib 1.0.1 requires seaborn<0.12.0,>=0.11.1, but you have seaborn 0.12.2 which is incompatible.
# medspacy 1.0.0 requires spacy>=3.4.1, but you have spacy 2.2.4 which is incompatible.
# medspacy-quickumls 2.6 requires spacy>=3.1.3, but you have spacy 2.2.4 which is incompatible.
# mxnet 1.8.0.post0 requires graphviz<0.9.0,>=0.8.1, but you have graphviz 0.20.1 which is incompatible.
# numba 0.54.1 requires numpy<1.21,>=1.17, but you have numpy 1.21.6 which is incompatible.
# panel 0.12.7 requires bokeh<2.5.0,>=2.4.0, but you have bokeh 2.0.0 which is incompatible.
# panel 0.12.7 requires setuptools<61,>=42, but you have setuptools 65.6.3 which is incompatible.
# pinecone-client 2.2.1 requires tqdm>=4.64.1, but you have tqdm 4.62.3 which is incompatible.
# pycaret 2.3.10 requires pyyaml<6.0.0, but you have pyyaml 6.0 which is incompatible.
# pytext-nlp 0.3.2 requires python-dateutil==2.8.0, but you have python-dateutil 2.8.2 which is incompatible.
# pytext-nlp 0.3.2 requires regex==2019.11.1, but you have regex 2022.10.31 which is incompatible.
# pytext-nlp 0.3.2 requires tensorboard==1.14, but you have tensorboard 2.11.2 which is incompatible.
# spyder 3.3.6 requires pyqt5<5.13; python_version >= "3", but you have pyqt5 5.15.4 which is incompatible.
# tensorboard 2.11.2 requires protobuf<4,>=3.9.2, but you have protobuf 4.23.2 which is incompatible.
# tensorflow 2.11.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 4.23.2 which is incompatible.
# tensorflow-text 2.8.2 requires tensorflow<2.9,>=2.8.0; platform_machine != "arm64" or platform_system != "Darwin", but you have tensorflow 2.11.0 which is incompatible.
# torchvision 0.14.0 requires torch==1.13.0, but you have torch 1.4.0 which is incompatible.
# yellowbrick 1.3.post1 requires numpy<1.20,>=1.16.0, but you have numpy 1.21.6 which is incompatible.
# Successfully installed cycler-0.11.0 fonttools-4.28.1 kiwisolver-1.4.4 matplotlib-3.5.3 numpy-1.21.6 packaging-23.1 pandas-1.3.5 pillow-9.5.0 pyparsing-3.0.9 python-dateutil-2.8.2 pytz-2023.3 seaborn-0.12.2 six-1.16.0 typing_extensions-4.6.3

# %%
sns.__version__
# Out:
# '0.12.2'

# %%
import seaborn as sns
import pandas as pd

df = sns.load_dataset("tips")

sns.scatterplot(df,
                x="total_bill",
                y="tip"
               )
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import seaborn as sns
import pandas as pd

df = sns.load_dataset("tips")

sns.scatterplot(df,
                x="total_bill",
                y="tip",
                hue='smoker'
               )
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
import seaborn as sns
import pandas as pd

df = sns.load_dataset("tips")

sns.scatterplot(df,
                x="total_bill",
                y="tip",
                hue='time',
                style='time'
               )
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=df, x="total_bill", y="tip", hue="day", style="time")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=df, x="total_bill", y="tip", hue="size")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
df = sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]
